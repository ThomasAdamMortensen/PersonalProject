# %% [markdown]
# First we gathered our data from our source

# %%
# Here the data scraping and cleaning will occur, still figuring out scraping this particular website.

# %%
import torch.nn as nn

# Here just a placeholder for the modeling section. 

model = nn.Sequential(
    nn.Linear(8, 24),
    nn.ReLU(),
    nn.Linear(24, 12),
    nn.ReLU(),
    nn.Linear(12, 6),
    nn.ReLU(),
    nn.Linear(6, 1)
)
